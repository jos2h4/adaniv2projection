# %% [markdown]
# <a href="https://colab.research.google.com/github/jos2h4/adaniv2projection/blob/main/Stock_Projection_Adani_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required packages (first cell)
# !pip install yfinance --upgrade

# Main code (second cell)
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from google.colab import files

# Set random seed for reproducibility
np.random.seed(42)

# Parameters
TICKER = 'ADANIPORTS.NS'
LOOK_BACK = 60  # Number of previous days to use for prediction
EPOCHS = 50
BATCH_SIZE = 32

# Set date range for the most recent data
start_date = datetime(2025, 2, 1)  # Starting from Feburary 2025
end_date = datetime(2025, 2, 5)    # Current date as per your system

print(f"Fetching data from {start_date.date()} to {end_date.date()}")

# Fetch stock data
print("Fetching stock data...")
try:
    # First, let's get historical data for training (2 years before start_date)
    historical_start = datetime(2023, 1, 1)  # 2 years of historical data
    stock_data = yf.download(TICKER, start=historical_start, end=end_date)

    if stock_data.empty:
        raise Exception("No data fetched")

    print(f"\nData range: from {stock_data.index.min()} to {stock_data.index.max()}")
    print(f"Total trading days: {len(stock_data)}")

    # Display the most recent month of data
    recent_data = stock_data['2025-02-01':]
    print("\nMost recent data (2025):")
    display(recent_data.head())

except Exception as e:
    print(f"Error fetching data: {e}")
    raise

# Display basic statistics of recent data
print("\nBasic statistics of the recent stock data (2025):")
display(recent_data.describe())

# Prepare data
print("\nPreparing data for LSTM...")
dataset = stock_data['Close'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# Create sequences for training
X, y = [], []
for i in range(LOOK_BACK, len(scaled_data)):
    X.append(scaled_data[i-LOOK_BACK:i, 0])
    y.append(scaled_data[i, 0])

X, y = np.array(X), np.array(y)
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# Split into train and test sets (80-20 split)
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print(f"\nTraining data size: {len(X_train)} days")
print(f"Testing data size: {len(X_test)} days")

# Create and compile LSTM model
print("\nCreating and training LSTM model...")
model = Sequential([
    LSTM(units=50, return_sequences=True, input_shape=(LOOK_BACK, 1)),
    Dropout(0.2),
    LSTM(units=50, return_sequences=False),
    Dropout(0.2),
    Dense(units=25),
    Dense(units=1)
])

model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model with progress bar
history = model.fit(
    X_train, y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_split=0.1,
    verbose=1
)

# Make predictions
print("\nMaking predictions...")
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse transform predictions
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)
y_train_actual = scaler.inverse_transform([y_train])
y_test_actual = scaler.inverse_transform([y_test])

# Calculate RMSE
train_rmse = np.sqrt(np.mean((train_predict - y_train_actual.T) ** 2))
test_rmse = np.sqrt(np.mean((test_predict - y_test_actual.T) ** 2))
print(f'\nTrain RMSE: {train_rmse:.2f}')
print(f'Test RMSE: {test_rmse:.2f}')

# Plot predictions (focus on 2025 data)
plt.figure(figsize=(16, 8))
recent_actual = y_test_actual.T[-len(recent_data):]
recent_pred = test_predict[-len(recent_data):]
plt.plot(recent_data.index, recent_actual, label='Actual Price', color='blue')
plt.plot(recent_data.index, recent_pred, label='Predicted Price', color='red', linestyle='--')
plt.title(f'{TICKER} Stock Price Prediction (2025)')
plt.xlabel('Date')
plt.ylabel('Stock Price (INR)')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot training history
plt.figure(figsize=(16, 8))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# Save predictions to CSV and download in Colab
results_df = pd.DataFrame({
    'Date': recent_data.index,
    'Actual': recent_actual.flatten(),
    'Predicted': recent_pred.flatten()
})
results_df.to_csv('ADANIPORTS_predictions_2025.csv')
files.download('ADANIPORTS_predictions_2025.csv')

# Print model summary
print("\nModel Summary:")
model.summary()

# Display final evaluation metrics
print("\nFinal Evaluation Metrics:")
print(f"Training RMSE: {train_rmse:.2f} INR")
print(f"Testing RMSE: {test_rmse:.2f} INR")

# Display recent predictions
print("\nMost Recent Predictions (2025):")
display(results_df.tail())
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.11/dist-packages (0.2.52)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.11/dist-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.11/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.11/dist-packages (from html5lib>=1.1->yfinance) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2024.12.14)
# [*********************100%***********************]  1 of 1 completed
# Fetching data from 2025-02-01 to 2025-02-05
# Fetching stock data...
#
# Data range: from 2023-01-02 00:00:00 to 2025-02-04 00:00:00
# Total trading days: 517
#
# Most recent data (2025):
# Price              Close          High           Low          Open  \
# Ticker     ADANIPORTS.NS ADANIPORTS.NS ADANIPORTS.NS ADANIPORTS.NS
# Date
# 2025-02-01   1084.099976   1117.500000       1063.00   1105.900024
# 2025-02-03   1084.849976   1094.000000       1055.00   1084.000000
# 2025-02-04   1125.099976   1127.900024       1091.75   1100.000000
#
# Price             Volume
# Ticker     ADANIPORTS.NS
# Date
# 2025-02-01       4919797
# 2025-02-03       3961203
# 2025-02-04       4070848
# Basic statistics of the recent stock data (2025):
# Price          Close          High           Low          Open        Volume
# Ticker ADANIPORTS.NS ADANIPORTS.NS ADANIPORTS.NS ADANIPORTS.NS ADANIPORTS.NS
# count       3.000000      3.000000      3.000000      3.000000  3.000000e+00
# mean     1098.016642   1113.133341   1069.916667   1096.633341  4.317283e+06
# std        23.457852     17.366741     19.326687     11.331529  5.246648e+05
# min      1084.099976   1094.000000   1055.000000   1084.000000  3.961203e+06
# 25%      1084.474976   1105.750000   1059.000000   1092.000000  4.016026e+06
# 50%      1084.849976   1117.500000   1063.000000   1100.000000  4.070848e+06
# 75%      1104.974976   1122.700012   1077.375000   1102.950012  4.495322e+06
# max      1125.099976   1127.900024   1091.750000   1105.900024  4.919797e+06
# Preparing data for LSTM...
#
# Training data size: 365 days
# Testing data size: 92 days
#
# Creating and training LSTM model...
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 137ms/step - loss: 0.0842 - val_loss: 0.0258
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0176 - val_loss: 0.0046
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0124 - val_loss: 0.0029
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0076 - val_loss: 0.0010
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0052 - val_loss: 0.0015
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0061 - val_loss: 0.0011
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0048 - val_loss: 0.0023
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0043 - val_loss: 0.0058
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0044 - val_loss: 0.0029
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0052 - val_loss: 5.8198e-04
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0052 - val_loss: 4.4243e-04
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0041 - val_loss: 0.0012
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0044 - val_loss: 0.0058
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.0041 - val_loss: 0.0057
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0040 - val_loss: 0.0036
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0038 - val_loss: 0.0040
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0044 - val_loss: 0.0037
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0031 - val_loss: 0.0019
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0031 - val_loss: 0.0016
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0028 - val_loss: 0.0020
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0034 - val_loss: 9.6399e-04
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0037 - val_loss: 5.3588e-04
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0033 - val_loss: 0.0045
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.0032 - val_loss: 4.8466e-04
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.0031 - val_loss: 8.1311e-04
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0030 - val_loss: 0.0043
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0035 - val_loss: 0.0012
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0033 - val_loss: 0.0022
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0031 - val_loss: 4.3487e-04
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0026 - val_loss: 9.1475e-04
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0029 - val_loss: 3.9971e-04
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0024 - val_loss: 0.0010
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0030 - val_loss: 4.1193e-04
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.0021 - val_loss: 9.6247e-04
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0025 - val_loss: 0.0010
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0026 - val_loss: 4.5683e-04
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0026 - val_loss: 4.6742e-04
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0022 - val_loss: 6.5228e-04
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0024 - val_loss: 3.9308e-04
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0026 - val_loss: 3.9185e-04
#
# Making predictions...
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Train RMSE: 41.78
# Test RMSE: 51.84
# Model Summary:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_14 (LSTM)                       │ (None, 60, 50)              │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 60, 50)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_15 (LSTM)                       │ (None, 50)                  │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_15 (Dropout)                 │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 25)                  │           1,275 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 1)                   │              26 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 95,705 (373.85 KB)
#  Trainable params: 31,901 (124.61 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 63,804 (249.24 KB)
# Final Evaluation Metrics:
# Training RMSE: 41.78 INR
# Testing RMSE: 51.84 INR
#
# Most Recent Predictions (2025):
#         Date       Actual    Predicted
# 0 2025-02-01  1084.099976  1113.239502
# 1 2025-02-03  1084.849976  1110.361084
# 2 2025-02-04  1125.099976  1107.813965
